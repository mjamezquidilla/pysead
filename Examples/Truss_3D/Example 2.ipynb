# %%
from pysead import Truss_3D
# %matplotlib widget
# Out:
# Positive Values for forces: right, up (righthand rule)
# Negative moment = clockwise, Positive moment = counter-clockwise (righthand rule)
# For adding Local Member Load: Axial Load is always parallel to the member local axis
# For adding Local Member Load: Loading is always point downward towards the frame element and is considered positive
# Member Forces: at left end to right end (based on local axis) - [Axial, Shear, Bending]. Local Axis is governed for positive/negative values. Right is positive, upward is positive, counterclockwise is positive
# Frame Reactions: [horizontal, vertical, Moment]. horizontal - right is positive, vertical - upward is positive, moment - counterclockwise is positive
# Frame Moment Release: All elements that is connected to the same release node should be released at node end of the element

# %%
nodes = {1: [-6*12,8*12,0], 2:[12*12,8*12,0], 3:[6*12,-8*12,0], 4:[-12*12,-8*12,0], 5:[0,0,24*12]}
elements = {1:[5,1], 2:[5,2], 3:[5,3], 4:[4,5]}
elasticity = {key: 10_000 for key in elements}
cross_area = {key: 8.4 for key in elements}
supports = {1:[1,1,1], 2:[1,1,1], 3:[1,1,1], 4:[1,1,1]}
forces = {5:[0,100,-50]}

# %%
Four_Bar_Truss = Truss_3D(nodes = nodes,
                          elements=elements,
                          elasticity=elasticity,
                          cross_area=cross_area,
                          supports=supports,
                          forces= forces)

# %%
Four_Bar_Truss.Solve()
# Out:
# Positive Stress/Force is in Tension, Negative Stress/Force is in Compression

# %%
Four_Bar_Truss.Draw_Truss_Setup(length_of_arrow=50)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Four_Bar_Truss.reactions_
# Out:
# {1: [28.47096, -37.96128, 113.88383],
#  2: [-30.55809, -20.37206, 61.11617],
#  3: [21.52904, -28.70539, -86.11617],
#  4: [-19.44191, -12.96128, -38.88383]}

# %%
Four_Bar_Truss.member_lengths_
# Out:
# {1: 312.0, 2: 336.0, 3: 312.0, 4: 336.0}

# %%
Four_Bar_Truss.member_forces_
# Out:
# {1: -123.37375739644972,
#  2: -71.3025,
#  3: 93.29281065088757,
#  4: 45.365357142857135}

# %%
Four_Bar_Truss.displacements_
# Out:
# {1: [0.0, 0.0, 0.0],
#  2: [0.0, 0.0, 0.0],
#  3: [0.0, 0.0, 0.0],
#  4: [0.0, 0.0, 0.0],
#  5: [-0.21825, 1.14405, -0.06052]}

# %%
Four_Bar_Truss.Draw_Truss_Displacements()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Four_Bar_Truss.Draw_Truss_Axial_Force_Map(figure_size=[7,7])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
