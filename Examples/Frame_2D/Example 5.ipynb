# %%
from pysead.Frame_2D import Frame_2D
from pysead.Frame_2D import Member_2D
import numpy as np
# Out:
# Positive Values for forces: right, up (righthand rule)
# Negative moment = clockwise, Positive moment = counter-clockwise (righthand rule)
# For adding Local Member Load: Axial Load is always parallel to the member local axis
# For adding Local Member Load: Loading is always point downward towards the frame element and is considered positive
# Member Forces: at left end to right end (based on local axis) - [Axial, Shear, Bending]. Local Axis is governed for positive/negative values. Right is positive, upward is positive, counterclockwise is positive
# Frame Reactions: [horizontal, vertical, Moment]. horizontal - right is positive, vertical - upward is positive, moment - counterclockwise is positive

# %%
E =  4500*np.sqrt(21)
I_column = 1/12*0.3*0.3**3
I_beam = 1/12*0.3*0.5**3
A_column = 0.3*0.3
A_beam = 0.3*0.5

# %%
# Columns
M1 = Member_2D(1, {1:[0,0],2:[0,3]}, A_column, E, I_column)
M2 = Member_2D(2, {2:[0,3],3:[0,6]}, A_column, E, I_column)
M3 = Member_2D(3, {3:[0,6],4:[0,9]}, A_column, E, I_column)
M4 = Member_2D(4, {4:[0,9],5:[0,12]}, A_column, E, I_column)
M5 = Member_2D(5, {5:[0,12],6:[0,15]}, A_column, E, I_column)
M6 = Member_2D(6, {6:[0,15],7:[0,18]}, A_column, E, I_column)
M7 = Member_2D(7, {7:[0,18],8:[0,21]}, A_column, E, I_column)
M8 = Member_2D(8, {8:[0,21],9:[0,24]}, A_column, E, I_column)
M9 = Member_2D(9, {9:[0,24],10:[0,27]}, A_column, E, I_column)
M10 = Member_2D(10, {10:[0,27],11:[0,30]}, A_column, E, I_column)

M11 = Member_2D(11, {12:[6,0], 13:[6,3]}, A_column, E, I_column)
M12 = Member_2D(12, {13:[6,3], 14:[6,6]}, A_column, E, I_column)
M13 = Member_2D(13, {14:[6,6], 15:[6,9]}, A_column, E, I_column)
M14 = Member_2D(14, {15:[6,9], 16:[6,12]}, A_column, E, I_column)
M15 = Member_2D(15, {16:[6,12],17:[6,15]}, A_column, E, I_column)
M16 = Member_2D(16, {17:[6,15],18:[6,18]}, A_column, E, I_column)
M17 = Member_2D(17, {18:[6,18],19:[6,21]}, A_column, E, I_column)
M18 = Member_2D(18, {19:[6,21],20:[6,24]}, A_column, E, I_column)
M19 = Member_2D(19, {20:[6,24],21:[6,27]}, A_column, E, I_column)
M20 = Member_2D(20, {21:[6,27],22:[6,30]}, A_column, E, I_column)

M21 = Member_2D(21, {23:[12,0], 24:[12,3]}, A_column, E, I_column)
M22 = Member_2D(22, {24:[12,3], 25:[12,6]}, A_column, E, I_column)
M23 = Member_2D(23, {25:[12,6], 26:[12,9]}, A_column, E, I_column)
M24 = Member_2D(24, {26:[12,9], 27:[12,12]}, A_column, E, I_column)
M25 = Member_2D(25, {27:[12,12],28:[12,15]}, A_column, E, I_column)
M26 = Member_2D(26, {28:[12,15],29:[12,18]}, A_column, E, I_column)
M27 = Member_2D(27, {29:[12,18],30:[12,21]}, A_column, E, I_column)
M28 = Member_2D(28, {30:[12,21],31:[12,24]}, A_column, E, I_column)
M29 = Member_2D(29, {31:[12,24],32:[12,27]}, A_column, E, I_column)
M30 = Member_2D(30, {32:[12,27],33:[12,30]}, A_column, E, I_column)

# Beams
M31 = Member_2D(31, {2:[0,3],13:[6,3]}, A_beam, E, I_beam)
M33 = Member_2D(33, {3:[0,6],14:[6,6]}, A_beam, E, I_beam)
M35 = Member_2D(35, {4:[0,9],15:[6,9]}, A_beam, E, I_beam)
M37 = Member_2D(37, {5:[0,12],16:[6,12]}, A_beam, E, I_beam)
M39 = Member_2D(39, {6:[0,15],17:[6,15]}, A_beam, E, I_beam)
M41 = Member_2D(41, {7:[0,18],18:[6,18]}, A_beam, E, I_beam)
M43 = Member_2D(43, {8:[0,21],19:[6,21]}, A_beam, E, I_beam)
M45 = Member_2D(45, {9:[0,24],20:[6,24]}, A_beam, E, I_beam)
M47 = Member_2D(47, {10:[0,27],21:[6,27]}, A_beam, E, I_beam)
M49 = Member_2D(49, {11:[0,30],22:[6,30]}, A_beam, E, I_beam)

M32 = Member_2D(32, {13:[6,3],24:[12,3]}, A_beam, E, I_beam)
M34 = Member_2D(34, {14:[6,6],25:[12,6]}, A_beam, E, I_beam)
M36 = Member_2D(36, {15:[6,9],26:[12,9]}, A_beam, E, I_beam)
M38 = Member_2D(38, {16:[6,12],27:[12,12]}, A_beam, E, I_beam)
M40 = Member_2D(40, {17:[6,15],28:[12,15]}, A_beam, E, I_beam)
M42 = Member_2D(42, {18:[6,18],29:[12,18]}, A_beam, E, I_beam)
M44 = Member_2D(44, {19:[6,21],30:[12,21]}, A_beam, E, I_beam)
M46 = Member_2D(46, {20:[6,24],31:[12,24]}, A_beam, E, I_beam)
M48 = Member_2D(48, {21:[6,27],32:[12,27]}, A_beam, E, I_beam)
M50 = Member_2D(50, {22:[6,30],33:[12,30]}, A_beam, E, I_beam)

# %%
Beams_List = [M31,M32,M33,M34,M35,M36,M37,M38,M39,M40,
              M41,M42,M43,M44,M45,M46,M47,M48,M49,M50]

# %%
for Beam in Beams_List:
    Beam.Add_Load_Full_Uniform(20)

# %%
members_list = [M1,M2,M3,M4,M5,M6,M7,M8,M9,M10,
               M11,M12,M13,M14,M15,M16,M17,M18,M19,M20,
               M21,M22,M23,M24,M25,M26,M27,M28,M29,M30,
               M31,M32,M33,M34,M35,M36,M37,M38,M39,M40,
               M41,M42,M43,M44,M45,M46,M47,M48,M49,M50]

# %%
Frame = Frame_2D()
Frame.Compile_Frame_Member_Properties(members_list)
Frame.supports = {1:[1,1,1], 12:[1,1,1], 23:[1,1,1]}

for i in range(2,12):
    Frame.Add_Load_Node({i:[10,0,0]})

Frame.Draw_Frame_Setup(figure_size = [10,10])

# %%
Frame.Solve()
Frame.Draw_Frame_Displacements(figure_size = [10,10], magnification_factor = 0.05)

# %%
Frame.reactions_
# Out:
# {1: [-23.35688, 486.2512, 45.64868],
#  12: [-38.71337, 1180.31737, 61.02172],
#  23: [-37.92974, 733.43143, 60.24825]}

# %%
M11.Plot_Diagrams(figure_size=[7,10])

# %%
Frame.solved_member_forces[32]
# Out:
# array([ -1.69441385, -17.18174054, -50.61470788,   1.69441385,
#         17.18174054, -52.47573534])

# %%
Frame.local_member_forces[32]
# Out:
# array([  0.,  60.,  60., -60.,  60., -60.])

# %%
Frame.local_member_forces_solved_[32]
# Out:
# array([  -1.69441385,   42.81825946,    9.38529212,  -58.30558615,
#          77.18174054, -112.47573534])

# %%
M32.Plot_Diagrams()

# %%
M32.shear
# Out:
# array([ 42.81825946,  38.68032843,  34.54239739,  30.40446636,
#         26.26653533,  22.12860429,  17.99067326,  13.85274222,
#          9.71481119,   5.57688015,   1.43894912,  -2.69898192,
#         -6.83691295, -10.97484398, -15.11277502, -19.25070605,
#        -23.38863709, -27.52656812, -31.66449916, -35.80243019,
#        -39.94036123, -44.07829226, -48.2162233 , -52.35415433,
#        -56.49208536, -60.6300164 , -64.76794743, -68.90587847,
#        -73.0438095 , -77.18174054])

# %%
M32.moment
# Out:
# array([  9.38529212,   0.95440371,  -6.62036103, -13.33900211,
#        -19.20151952, -24.20791327, -28.35818337, -31.65232979,
#        -34.09035256, -35.67225167, -36.39802711, -36.26767889,
#        -35.281207  , -33.43861146, -30.73989225, -27.18504938,
#        -22.77408285, -17.50699266, -11.3837788 ,  -4.40444128,
#          3.4310199 ,  12.12260474,  21.67031325,  32.07414542,
#         43.33410125,  55.45018074,  68.4223839 ,  82.25071071,
#         96.93516119, 112.47573534])
