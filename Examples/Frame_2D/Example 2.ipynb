# %%
from pysead.Frame_2D import Frame_2D
from pysead.Frame_2D import Member_2D
import numpy as np
# Out:
# Positive Values for forces: right, up (righthand rule)
# Negative moment = clockwise, Positive moment = counter-clockwise (righthand rule)
# For adding Local Member Load: Axial Load is always parallel to the member local axis
# For adding Local Member Load: Loading is always point downward towards the frame element and is considered positive
# Member Forces: at left end to right end (based on local axis) - [Axial, Shear, Bending]. Local Axis is governed for positive/negative values. Right is positive, upward is positive, counterclockwise is positive
# Frame Reactions: [horizontal, vertical, Moment]. horizontal - right is positive, vertical - upward is positive, moment - counterclockwise is positive

# %%
M1 = Member_2D(member_number = 1, 
               nodes = {1:[0,0], 2:[0,3]},
               area = 2e-2,
               inertia = 5e-5,
               elasticity= 210_000_000)
M2 = Member_2D(member_number = 2, 
               nodes = {2:[0,3], 3:[4,3]},
               area = 2e-2,
               inertia = 5e-5,
               elasticity= 210_000_000)
M3 = Member_2D(member_number = 3, 
               nodes = {3:[4,3], 4:[4,0]},
               area = 2e-2,
               inertia = 5e-5,
               elasticity= 210_000_000)
Frame = Frame_2D()
Frame.Compile_Frame_Member_Properties([M1,M2,M3])
Frame.supports = {1:[1,1,1], 4:[1,1,1]}
Frame.Add_Load_Node({2:[-20,0,0], 3:[0,0,12]})
Frame.Solve()

# %%
Frame.displacements_
# Out:
# {1: [0.0, 0.0, 0.0],
#  2: [-0.0037867035375034118, -6.13322732693502e-06, 0.0007830822583884874],
#  3: [-0.0037792651635665513, 6.133227326935019e-06, 0.0014037540185153432],
#  4: [0.0, 0.0, 0.0]}

# %%
Frame.local_member_forces
# Out:
# {1: array([0, 0, 0, 0, 0, 0]),
#  2: array([0, 0, 0, 0, 0, 0]),
#  3: array([0, 0, 0, 0, 0, 0])}

# %%
Frame.solved_member_forces
# Out:
# {1: array([  8.58651826, -12.18970737, -21.02534895,  -8.58651826,
#          12.18970737, -15.54377315]),
#  2: array([-7.81029263,  8.58651826, 15.54377315,  7.81029263, -8.58651826,
#         18.80229989]),
#  3: array([ -8.58651826,  -7.81029263,  -6.80229989,   8.58651826,
#           7.81029263, -16.62857802])}

# %%
Frame.local_member_forces_solved_
# Out:
# {1: array([  8.58651826, -12.18970737, -21.02534895,  -8.58651826,
#          12.18970737, -15.54377315]),
#  2: array([-7.81029263,  8.58651826, 15.54377315,  7.81029263, -8.58651826,
#         18.80229989]),
#  3: array([ -8.58651826,  -7.81029263,  -6.80229989,   8.58651826,
#           7.81029263, -16.62857802])}

# %%
Frame.displacements_
# Out:
# {1: [0.0, 0.0, 0.0],
#  2: [-0.0037867035375034118, -6.13322732693502e-06, 0.0007830822583884874],
#  3: [-0.0037792651635665513, 6.133227326935019e-06, 0.0014037540185153432],
#  4: [0.0, 0.0, 0.0]}

# %%
Frame.Draw_Frame_Setup(figure_size=[10,10], arrow_line_width=3)

# %%
Frame.Draw_Frame_Displacements(figure_size=[10,10], magnification_factor=100)

# %%
Frame.reactions_
# Out:
# array([ 12.18971,   8.58652, -21.02535, -20.     ,  -0.     ,  -0.     ,
#         -0.     ,   0.     ,  12.     ,   7.81029,  -8.58652, -16.62858])

# %%
M1.Plot_Diagrams()

# %%
M2.Plot_Diagrams()

# %%
M3.Plot_Diagrams()
