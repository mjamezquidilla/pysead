# %%
from pysead.Frame_2D import Frame_2D
from pysead.Frame_2D import Member_2D
import numpy as np
# Out:
# Positive Values for forces: right, up (righthand rule)
# Negative moment = clockwise, Positive moment = counter-clockwise (righthand rule)
# For adding Local Member Load: Axial Load is always parallel to the member local axis
# For adding Local Member Load: Loading is always point downward towards the frame element and is considered positive
# Member Forces: at left end to right end (based on local axis) - [Axial, Shear, Bending]. Local Axis is governed for positive/negative values. Right is positive, upward is positive, counterclockwise is positive
# Frame Reactions: [horizontal, vertical, Moment]. horizontal - right is positive, vertical - upward is positive, moment - counterclockwise is positive
# Frame Moment Release: All elements that is connected to the same release node should be released at node end of the element

# %%
E =  4700*np.sqrt(21) * 1000
I_column = 1/12*0.3*0.3**3
I_beam = 1/12*0.3*0.5**3
A_column = 0.3*0.3
A_beam = 0.3*0.5

# %%
# Columns
M1 = Member_2D(1,A_column, E, I_column, {1:[0,0],2:[0,3]})
M2 = Member_2D(2,A_column, E, I_column, {2:[0,3],3:[0,6]})
M3 = Member_2D(3,A_column, E, I_column, {3:[0,6],4:[0,9]})
M4 = Member_2D(4,A_column, E, I_column, {4:[0,9],5:[0,12]})
M5 = Member_2D(5,A_column, E, I_column, {5:[0,12],6:[0,15]})
M6 = Member_2D(6,A_column, E, I_column, {6:[0,15],7:[0,18]})
M7 = Member_2D(7,A_column, E, I_column, {7:[0,18],8:[0,21]})
M8 = Member_2D(8,A_column, E, I_column, {8:[0,21],9:[0,24]})
M9 = Member_2D(9,A_column, E, I_column, {9:[0,24],10:[0,27]})
M10 = Member_2D(10,A_column, E, I_column, {10:[0,27],11:[0,30]})

M11 = Member_2D(11, A_column, E, I_column, {12:[6,0], 13:[6,3]})
M12 = Member_2D(12, A_column, E, I_column, {13:[6,3], 14:[6,6]})
M13 = Member_2D(13, A_column, E, I_column, {14:[6,6], 15:[6,9]})
M14 = Member_2D(14, A_column, E, I_column, {15:[6,9], 16:[6,12]})
M15 = Member_2D(15, A_column, E, I_column, {16:[6,12],17:[6,15]})
M16 = Member_2D(16, A_column, E, I_column, {17:[6,15],18:[6,18]})
M17 = Member_2D(17, A_column, E, I_column, {18:[6,18],19:[6,21]})
M18 = Member_2D(18, A_column, E, I_column, {19:[6,21],20:[6,24]})
M19 = Member_2D(19, A_column, E, I_column, {20:[6,24],21:[6,27]})
M20 = Member_2D(20, A_column, E, I_column, {21:[6,27],22:[6,30]})

M21 = Member_2D(21, A_column, E, I_column, {23:[12,0], 24:[12,3]})
M22 = Member_2D(22, A_column, E, I_column, {24:[12,3], 25:[12,6]})
M23 = Member_2D(23, A_column, E, I_column, {25:[12,6], 26:[12,9]})
M24 = Member_2D(24, A_column, E, I_column, {26:[12,9], 27:[12,12]})
M25 = Member_2D(25, A_column, E, I_column, {27:[12,12],28:[12,15]})
M26 = Member_2D(26, A_column, E, I_column, {28:[12,15],29:[12,18]})
M27 = Member_2D(27, A_column, E, I_column, {29:[12,18],30:[12,21]})
M28 = Member_2D(28, A_column, E, I_column, {30:[12,21],31:[12,24]})
M29 = Member_2D(29, A_column, E, I_column, {31:[12,24],32:[12,27]})
M30 = Member_2D(30, A_column, E, I_column, {32:[12,27],33:[12,30]})

# Beams
M31 = Member_2D(31, A_beam, E, I_beam, {2:[0,3],13:[6,3]})
M33 = Member_2D(33, A_beam, E, I_beam, {3:[0,6],14:[6,6]})
M35 = Member_2D(35, A_beam, E, I_beam, {4:[0,9],15:[6,9]})
M37 = Member_2D(37, A_beam, E, I_beam, {5:[0,12],16:[6,12]})
M39 = Member_2D(39, A_beam, E, I_beam, {6:[0,15],17:[6,15]})
M41 = Member_2D(41, A_beam, E, I_beam, {7:[0,18],18:[6,18]})
M43 = Member_2D(43, A_beam, E, I_beam, {8:[0,21],19:[6,21]})
M45 = Member_2D(45, A_beam, E, I_beam, {9:[0,24],20:[6,24]})
M47 = Member_2D(47, A_beam, E, I_beam, {10:[0,27],21:[6,27]})
M49 = Member_2D(49, A_beam, E, I_beam, {11:[0,30],22:[6,30]})

M32 = Member_2D(32, A_beam, E, I_beam, {13:[6,3],24:[12,3]})
M34 = Member_2D(34, A_beam, E, I_beam, {14:[6,6],25:[12,6]})
M36 = Member_2D(36, A_beam, E, I_beam, {15:[6,9],26:[12,9]})
M38 = Member_2D(38, A_beam, E, I_beam, {16:[6,12],27:[12,12]})
M40 = Member_2D(40, A_beam, E, I_beam, {17:[6,15],28:[12,15]})
M42 = Member_2D(42, A_beam, E, I_beam, {18:[6,18],29:[12,18]})
M44 = Member_2D(44, A_beam, E, I_beam, {19:[6,21],30:[12,21]})
M46 = Member_2D(46, A_beam, E, I_beam, {20:[6,24],31:[12,24]})
M48 = Member_2D(48, A_beam, E, I_beam, {21:[6,27],32:[12,27]})
M50 = Member_2D(50, A_beam, E, I_beam, {22:[6,30],33:[12,30]})

# %%
Beams_List = [M31,M32,M33,M34,M35,M36,M37,M38,M39,M40,
              M41,M42,M43,M44,M45,M46,M47,M48,M49,M50]

# %%
for Beam in Beams_List:
    Beam.Add_Load_Full_Uniform(20)

# %%
members_list = [M1,M2,M3,M4,M5,M6,M7,M8,M9,M10,
               M11,M12,M13,M14,M15,M16,M17,M18,M19,M20,
               M21,M22,M23,M24,M25,M26,M27,M28,M29,M30,
               M31,M32,M33,M34,M35,M36,M37,M38,M39,M40,
               M41,M42,M43,M44,M45,M46,M47,M48,M49,M50]

# %%
for member in members_list:
    member.Add_Self_Weight(23.5631)

# %%
Frame = Frame_2D()
Frame.Compile_Frame_Member_Properties(members_list)
Frame.supports = {1:[1,1,1], 12:[1,1,1], 23:[1,1,1]}

for i in range(2,12):
    Frame.Add_Load_Node({i:[10,0,0]})

Frame.Draw_Frame_Setup(figure_size = [8,20], width_of_arrow=0.2, radius_of_arc=1)

# %%
Frame.Solve()
Frame.Draw_Frame_Displacements(figure_size = [8,14], magnification_factor = 20)

# %%
Frame.reactions_
# Out:
# {1: [-22.06059994387368, 657.6465240943595, 44.34479116050544],
#  12: [-38.71337373894369, 1452.5236365167223, 61.021718177039205],
#  23: [-39.22602631719155, 904.8267493889077, 61.55213889555497]}

# %%
Frame.displacements_
# Out:
# {1: [0.0, 0.0, 0.0],
#  2: [0.006897601692069244, -0.0010128800132130017, -0.0023222698859221113],
#  3: [0.014976351125329865, -0.001950417281228134, -0.002234534935765311],
#  4: [0.022301282800077163, -0.002805844862920342, -0.002204283855241287],
#  5: [0.02879786297601663, -0.0035724911830335854, -0.0021391357920470143],
#  6: [0.03444462301423828, -0.004243881525516975, -0.002059734518354189],
#  7: [0.0392301300414379, -0.004813961384432753, -0.0019659352831712922],
#  8: [0.04314452977531878, -0.005277061418833834, -0.0018583184339960993],
#  9: [0.046181480847258705, -0.005627863748742398, -0.0017465265874387873],
#  10: [0.04832238179495039, -0.005861530441917336, -0.0015463798379860023],
#  11: [0.049663245925657976, -0.00597224321852487, -0.0020794918375262434],
#  12: [0.0, 0.0, 0.0],
#  13: [0.00690507781267949, -0.0022430672931398514, -0.0006090822575169325],
#  14: [0.01496470145454054, -0.004239177472660237, -0.0006598990360390581],
#  15: [0.02229093409813669, -0.005998468904217934, -0.0006071553317702886],
#  16: [0.028786887194266045, -0.007526711838524169, -0.0005532252884976271],
#  17: [0.034433268705871545, -0.00882913508525527, -0.000494231321591659],
#  18: [0.03921838610410004, -0.009910111765761207, -0.0004317754587523494],
#  19: [0.04313253806739964, -0.010773244844690704, -0.00036642676938126247],
#  20: [0.046168046818682265, -0.01142143445378111, -0.00029868281191139585],
#  21: [0.04831940387591653, -0.011856620829564454, -0.00023086987047458467],
#  22: [0.04959549886972801, -0.012082736567702434, -0.00015774542474860124],
#  23: [0.0, 0.0, 0.0],
#  24: [0.006910577565988256, -0.0013954271569848714, -0.0005598551596994717],
#  25: [0.014961817791066942, -0.0026465398006110252, -0.0004548999222398436],
#  26: [0.022288628623310103, -0.0037499665063467397, -0.00023710575745326503],
#  27: [0.028784073639346534, -0.004706608598736829, -2.8737979579293474e-05],
#  28: [0.034430063469929925, -0.005517711984155849, 0.00017288909287547496],
#  29: [0.039214793270041556, -0.00618495804719159, 0.00036736671064549974],
#  30: [0.04312869441038157, -0.006710413164142421, 0.0005538396405848998],
#  31: [0.04616278258625411, -0.007096495083248808, 0.0007403721859524865],
#  32: [0.04832439222867482, -0.007346101500219834, 0.0008430346390985417],
#  33: [0.049536069878409736, -0.007461118099227577, 0.001650790889870545]}

# %%
M11.Plot_Diagrams(figure_size=[15,15])

# %%
M1.Plot_Diagrams()

# %%
Frame.solved_member_forces[32]
# Out:
# array([ -2.96135671, -16.28240557, -49.39943465,   2.96135671,
#         16.28240557, -48.29499877])

# %%
Frame.local_member_forces[32]
# Out:
# array([  0.      ,  70.603395,  70.603395,   0.      ,  70.603395,
#        -70.603395])

# %%
Frame.local_member_forces_solved_[32]
# Out:
# array([  -2.96135671,   54.32098943,   21.20396035,    2.96135671,
#          86.88580057, -118.89839377])

# %%
M32.Plot_Diagrams()

# %%
M32.shear
# Out:
# array([ 54.32098943,  40.20031043,  26.07963143,  11.95895243,
#         -2.16172657, -16.28240557, -30.40308457, -44.52376357,
#        -58.64444257, -72.76512157, -86.88580057])

# %%
M32.moment
# Out:
# array([ 21.20396035,  -7.15242961, -27.03641216, -38.44798732,
#        -41.38715508, -35.85391544, -21.8482684 ,   0.62978605,
#         31.58024789,  71.00311713, 118.89839377])

# %%
M31.Summary()
# Out:
# At Left End:
# Axial: -4.025536910626215
# Shear: 42.32016344383639
# Moment: -33.46443317791504
#
# At Right End:
# Axial: -4.025536910626215
# Shear: -98.88662655616362
# Moment: 136.23495615906666
#
# Minimum and Maximum
# Minimum Shear: -98.88662655616362
# Maximum Shear: 42.32016344383639
# Minimum Moment: -71.51489407682053
# Maximum Moment: 136.23495615906666

# %%
M32.Summary()
# Out:
# At Left End:
# Axial: -2.961356711317876
# Shear: 54.32098943006748
# Moment: 21.203960353035697
#
# At Right End:
# Axial: -2.961356711317876
# Shear: -86.88580056993254
# Moment: 118.89839377263088
#
# Minimum and Maximum
# Minimum Shear: -86.88580056993254
# Maximum Shear: 54.32098943006748
# Minimum Moment: -41.387155079126245
# Maximum Moment: 118.89839377263088

# %%
M11.Summary()
# Out:
# At Left End:
# Axial: 1446.1615995167224
# Shear: 38.71337373894369
# Moment: 61.021718177039205
#
# At Right End:
# Axial: 1446.1615995167224
# Shear: 38.71337373894369
# Moment: -55.11840303979186
#
# Minimum and Maximum
# Minimum Shear: 38.71337373894369
# Maximum Shear: 38.71337373894369
# Minimum Moment: -55.11840303979186
# Maximum Moment: 61.021718177039205

# %%
M12.Summary()
# Out:
# At Left End:
# Axial: 1286.5919465304917
# Shear: 39.77755393824931
# Moment: 59.91259276623914
#
# At Right End:
# Axial: 1286.5919465304917
# Shear: 39.77755393824931
# Moment: -59.42006904850879
#
# Minimum and Maximum
# Minimum Shear: 39.77755393824931
# Maximum Shear: 39.77755393824931
# Minimum Moment: -59.42006904850879
# Maximum Moment: 59.91259276623914

# %%
M32.moment
# Out:
# array([ 21.20396035,  -7.15242961, -27.03641216, -38.44798732,
#        -41.38715508, -35.85391544, -21.8482684 ,   0.62978605,
#         31.58024789,  71.00311713, 118.89839377])

# %%
M32.Summary()
# Out:
# At Left End:
# Axial: -2.961356711317876
# Shear: 54.32098943006748
# Moment: 21.203960353035697
#
# At Right End:
# Axial: -2.961356711317876
# Shear: -86.88580056993254
# Moment: 118.89839377263088
#
# Minimum and Maximum
# Minimum Shear: -86.88580056993254
# Maximum Shear: 54.32098943006748
# Minimum Moment: -41.387155079126245
# Maximum Moment: 118.89839377263088

# %%
M32.Plot_Diagrams(figure_size=[10,12])

# %%
Frame.elements
# Out:
# {1: [1, 2],
#  2: [2, 3],
#  3: [3, 4],
#  4: [4, 5],
#  5: [5, 6],
#  6: [6, 7],
#  7: [7, 8],
#  8: [8, 9],
#  9: [9, 10],
#  10: [10, 11],
#  11: [12, 13],
#  12: [13, 14],
#  13: [14, 15],
#  14: [15, 16],
#  15: [16, 17],
#  16: [17, 18],
#  17: [18, 19],
#  18: [19, 20],
#  19: [20, 21],
#  20: [21, 22],
#  21: [23, 24],
#  22: [24, 25],
#  23: [25, 26],
#  24: [26, 27],
#  25: [27, 28],
#  26: [28, 29],
#  27: [29, 30],
#  28: [30, 31],
#  29: [31, 32],
#  30: [32, 33],
#  31: [2, 13],
#  32: [13, 24],
#  33: [3, 14],
#  34: [14, 25],
#  35: [4, 15],
#  36: [15, 26],
#  37: [5, 16],
#  38: [16, 27],
#  39: [6, 17],
#  40: [17, 28],
#  41: [7, 18],
#  42: [18, 29],
#  43: [8, 19],
#  44: [19, 30],
#  45: [9, 20],
#  46: [20, 31],
#  47: [10, 21],
#  48: [21, 32],
#  49: [11, 22],
#  50: [22, 33]}
