# %%
from pysead.Frame_2D import Frame_2D
from pysead.Frame_2D import Member_2D
# Out:
# Positive Values for forces: right, up (righthand rule)
# Negative moment = clockwise, Positive moment = counter-clockwise (righthand rule)
# For adding Local Member Load: Axial Load is always parallel to the member local axis
# For adding Local Member Load: Loading is always point downward towards the frame element and is considered positive
# Member Forces: at left end to right end (based on local axis) - [Axial, Shear, Bending]. Local Axis is governed for positive/negative values. Right is positive, upward is positive, counterclockwise is positive
# Frame Reactions: [horizontal, vertical, Moment]. horizontal - right is positive, vertical - upward is positive, moment - counterclockwise is positive
# Frame Moment Release: All elements that is connected to the same release node should be released at node end of the element

# %%
M1 = Member_2D(1,14.7, 29_000, 800, {1:[0,0], 2:[0,20*12]}, [0,1],no_of_divs=100)
M2 = Member_2D(2,14.7, 29_000, 800, {2:[0,20*12], 3:[20*12,20*12]}, [1,0],no_of_divs=100)
M3 = Member_2D(3,14.7, 29_000, 800, {3:[20*12,20*12], 4:[20*12,0]}, [0,0],no_of_divs=100)
M1.Add_Load_Full_Uniform(0.1)
M2.Add_Load_Point(75,10*12)

# %%
M1.Plot_Diagrams(show_annotation=False)

# %%
M2.Plot_Diagrams(show_annotation=False)

# %%
M3.Plot_Diagrams(show_annotation=False)

# %%
Frame = Frame_2D()
Frame.Compile_Frame_Member_Properties([M1,M2,M3])
Frame.Add_Load_Node({2:[25,0,0]})
Frame.supports = {1:[1,1,1], 4:[1,1,0]}

# %%
Frame.Draw_Frame_Setup(figure_size=[10,10], length_of_arrow=30, linewidth = 4,radius_of_arc=30)

# %%
Frame.Solve()

# %%
Frame.reactions_
# Out:
# {1: [-33.02444884115273, 21.52444884115343, 5045.867721876657],
#  4: [-15.975551158846597, 53.47555115884657, 3.410605131648481e-13]}

# %%
M1.Summary()
# Out:
# At Left End:
# Axial: 21.52444884115343
# Shear: 33.02444884115273
# Moment: 5045.867721876657
#
# At Right End:
# Axial: 21.52444884115343
# Shear: 9.024448841152736
# Moment: 0.0
#
# Minimum and Maximum
# Minimum Shear: 9.024448841152736
# Maximum Shear: 33.02444884115273
# Minimum Moment: 0.0
# Maximum Moment: 5045.867721876657

# %%
M2.Summary()
# Out:
# At Left End:
# Axial: 15.975551158848248
# Shear: 21.524448841153422
# Moment: 0.0
#
# At Right End:
# Axial: 15.975551158848248
# Shear: -53.47555115884658
# Moment: 3834.1322781231784
#
# Minimum and Maximum
# Minimum Shear: -53.47555115884658
# Maximum Shear: 21.524448841153422
# Minimum Moment: -2556.8436199188313
# Maximum Moment: 3834.1322781231784

# %%
M3.Summary()
# Out:
# At Left End:
# Axial: 53.47555115884657
# Shear: 15.975551158846597
# Moment: 3834.1322781231784
#
# At Right End:
# Axial: 53.47555115884657
# Shear: 15.975551158846597
# Moment: -5.002220859751105e-12
#
# Minimum and Maximum
# Minimum Shear: 15.975551158846597
# Maximum Shear: 15.975551158846597
# Minimum Moment: -5.002220859751105e-12
# Maximum Moment: 3834.1322781231784

# %%
M1.Plot_Diagrams(show_annotation=False)

# %%
M2.Plot_Diagrams(show_annotation=False)

# %%
M3.Plot_Diagrams(show_annotation=False)
